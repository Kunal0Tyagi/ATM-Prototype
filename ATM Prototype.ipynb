# %%
a={"Kunal":[120321569875,1120,100000],
 "Amit":[126548321901,1130,200000],
   "Aalash":[123675219450,1129,307500],
   "Rahul":[129547536105,1139,480036],
   "Harsh":[124578236910,1128,98000]}

#if u want to try different choices u have enter the username and pin again , as in a atm u have to reinsert ur atm card to do somethig else

while(1):
        
        a1=input("please enter ur username without any whitespaces:")#u have to enter the name that matches with the database 
        t=1
        
        for i in a:
                
                
                if(a1.casefold()==i.casefold()):
                    
                    print("\n....................Welcome to the ATM ",i,end=(" ............................"))
                    c=int(input("\nplease enter ur pin:"))
                    if(int(a[i][1])==c):
                        flag=1
                        while(flag==1):
                            print("\n1.Cash Withdrawl")
                            print("\n2.Cash Deposit")
                            print("\n3.Change pin")
                            print("\n4.Account details")
                            print("\n5.Money Transfer")
                            b=int(input("Please enter ur choice:")) 
                            if(b==1):
                                wid=int(input("Please enter the amount u want to withdraw:"))
                                a[i][2]=a[i][2]-wid
                                print("\nBalance info: $",a[i][2])
                                print("\nThank You , Visit again")
                                t=0
                                print("\nplease enter 1 if u want to try other choices or enter 0:")
                                flag=int(input())
                            elif(b==2):
                                depo=int(input("please enter the amount u want to deposit:"))
                                a[i][2]=a[i][2]+depo
                                print("\naccount balance:",a[i][2])
                                print("\nThank You , Visit Again")
                                t=0
                                print("\nplease enter 1 if u want to try other choices or enter 0:")
                                flag=int(input())
                            
                            elif(b==3):
                                oldpin=int(input("\nplease enter ur old pin:"))
                                if(oldpin==a[i][1]):
                                    newpin=input("please enter ur new pin:")
                                    print("pin changed successfully")
                                    
                                    a[i].insert(2,newpin)
                                    a[i].pop(1)
                                    t=0
                                    print("\nplease enter the username and pin again ,as the pin has been changed")
                                    break#enter again with the new pincode 
                                else:
                                    print("\nwrong old pin")
                                    t=0
                                print("\nplease enter 1 if u want to try other choices or enter 0:")
                                flag=int(input())
                            elif(b==4):
                                print("\nUsername:",i)
                                print("\nAccount Number:",a[i][0])
                                print("\nBalance:",a[i][2])
                                t=0
                                print("\nplease enter 1 if u want to try other choices or enter 0:")
                                flag=int(input())
                            elif(b==5):
                                h=int(input("\nenter the account number of the person u want to transfer the money to:"))
                                z=0
                                for k in a:
                                                                   
                                    if(a[k][0]==h):
                                        print("\nname of the account holder:",k)
                                        g=int(input("\nplease enter the amount u want to transfer:"))
                                        newamt=a[k][2]+g
                                        a[k].append(newamt)
                                        a[k].pop(2)
                                        newamt1=a[i][2]-g
                                        a[i].append(newamt1)
                                        a[i].pop(2)
                                        print("\nbalance left:",a[i][2])
                                        t=0
                                        z=1
                                    if(z==0):
                                        print("\nuser info not found")
                                print("\nplease enter 1 if u want to try other choices or enter 0:")
                                flag=int(input())
           
        if(t==1):
            print("\n***No such username(matching the pin or username itself) exists in the database***\ntry again")
# Out:
# please enter ur username without any whitespaces:kunal
#
# ***No such username(matching the pin or username itself) exists in the database***
# try again
# please enter ur username without any whitespaces:kunal
#
# ....................Welcome to the ATM  Kunal ............................
# please enter ur pin:1120
#
# 1.Cash Withdrawl
#
# 2.Cash Deposit
#
# 3.Change pin
#
# 4.Account details
#
# 5.Money Transfer
# Please enter ur choice:4
#
# Username: Kunal
#
# Account Number: 120321569875
#
# Balance: 100000
#
# please enter 1 if u want to try other choices or enter 0:
# 1
#
# 1.Cash Withdrawl
#
# 2.Cash Deposit
#
# 3.Change pin
#
# 4.Account details
#
# 5.Money Transfer
# Please enter ur choice:1
# Please enter the amount u want to withdraw:6000
#
# Balance info: $ 94000
#
# Thank You , Visit again
#
# please enter 1 if u want to try other choices or enter 0:
# 1
#
# 1.Cash Withdrawl
#
# 2.Cash Deposit
#
# 3.Change pin
#
# 4.Account details
#
# 5.Money Transfer
# ...
